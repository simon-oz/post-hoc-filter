# %%
from datasets import Dataset

# Load the Arrow file
dataset = Dataset.from_file('ms_marco-test.arrow')

# Convert to pandas if needed
df = dataset.to_pandas()

print(f"Dataset info: {dataset}")
print(df.head())
